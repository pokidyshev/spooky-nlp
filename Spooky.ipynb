# %% [markdown]
# # Ideas
#
# - Sentiment analisys
# - [spaCy][1]
# - Vis
#     - word trees
#     - bubble chart (top words)
#     - [scattertext][2]
# - Text Mining and Visualization [book][3]
# - Applied Text Mining in Python on [coursera][4]
#
# [1]: https://github.com/explosion/spaCy
# [2]: https://github.com/JasonKessler/scattertext
# [3]: https://www.google.ru/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&ved=0ahUKEwja1azlqpDXAhVkOpoKHTR-DKQQFggpMAA&url=https%3A%2F%2Fdoc.lagout.org%2FOthers%2FData%2520Mining%2FText%2520Mining%2520and%2520Visualization_%2520Case%2520Studies%2520using%2520Open-Source%2520Tools%2520%255BHofmann%2520%2526%2520Chisholm%25202015-12-18%255D.pdf&usg=AOvVaw192OqWLftT7fQpwWxMaLSh
# [4]: https://www.coursera.org/learn/python-text-mining/home/week/4

# %% [markdown]
# # EDA

# %% [markdown]
# ## import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
sns.set()

from wordcloud import WordCloud, STOPWORDS

pd.options.display.max_colwidth = 160

# %% [markdown]
# ## Load data

# %%
train = pd.read_csv('data/train.zip')
test  = pd.read_csv('data/test.zip')

sample_submission = pd.read_csv('data/sample_submission.zip')

# %%
sample_submission.head(1)
# Out:
#         id       EAP       HPL       MWS
# 0  id02310  0.403494  0.287808  0.308698

# %%
display(train.shape, test.shape)
# Out:
# (19579, 3)
# (8392, 2)

# %%
train.head(2)
# Out:
#         id  \
# 0  id26305
# 1  id17569
#
#                                                                                                                                                               text  \
# 0  This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set ...
# 1                                                                                          It never once occurred to me that the fumbling might be a mere mistake.
#
#   author
# 0    EAP
# 1    HPL

# %% [markdown]
# ## Visualization

# %%
sns.countplot(x=train.author);

# %% [markdown]
# ### Word Clouds

# %%
eap = train[train.author=='EAP'].text
hpl = train[train.author=='HPL'].text
mws = train[train.author=='MWS'].text

# %%
sns.set_style('whitegrid', {'axes.grid' : False})

# %%
WordCloud(stopwords=STOPWORDS, min_font_size=8, width=1000, height=400)\
    .generate(' '.join(eap))\
    .to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x7F808DD2FFD0>

# %%
WordCloud(stopwords=STOPWORDS, min_font_size=8, width=1000, height=400, colormap='cubehelix_r')\
    .generate(' '.join(hpl))\
    .to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x7F80D0FBE208>

# %%
WordCloud(stopwords=STOPWORDS, min_font_size=8, width=1000, height=400, colormap='hot')\
    .generate(' '.join(mws))\
    .to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x7F808DE584A8>

# %% [markdown]
# # Preprocessing

# %%
import spacy
nlp = spacy.load('en')
# Out:
#     Warning: no model found for 'en'
#
#     Only loading the 'en' tokenizer.
